# %% [markdown]
# # Scenario Construction
# Demand and dispatch data are obtained from the Australian Energy Market Operator's (AEMO's) Market Management System Database Model (MMSDM) [1], and a k-means clustering algorithm is implemented using the method outlined in [2] to create a reduced set of representative operating scenarios. The dataset described in [3,4] is used to identify specific generators, and assign historic power injections or withdrawals to individual nodes.
#
# In this analysis data for 2017 is considered, with demand and dispatch time series re-sampled to 30min intervals, corresponding to the length of a trading interval within Australia's National Electricity Market (NEM). For each week in 2017 a reduced set of 10 operating scenarios with associated durations is created. This reduces the number of scenarios from:
#
# - 365 days/year $\times$ 48 trading intervals/day = 17520 trading intervals/year
#
# to
#
# - 52 weeks/year $\times$ 10 operating scenarios/week = 520 operating scenarios/year.
#
# **Note:** If seeking to construct these scenarios on your local machine, you must download the relevant MMSDM archives from NEMWEB [http://www.nemweb.com.au/#mms-data-model](http://www.nemweb.com.au/#mms-data-model). To replicate this analysis download all monthly archives for 2017 and place these zipped files in a single directory. Update the parameter `archive_dir` below to point to this directory.
#
# ## Import packages

# %%
import os
import math
import pickle
import random
import zipfile
from io import BytesIO

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Initialise random number generator
random.seed(1)

# Used to slice pandas DataFrames
idx = pd.IndexSlice

# %% [markdown]
# ## Paths to files

# %%
# Contains network information and generator parameters
data_dir = os.path.join(os.path.curdir, os.path.pardir, os.path.pardir, 'data', 'egrimod-nem-dataset-v1.3', 'akxen-egrimod-nem-dataset-4806603')

# MMSDM historic demand and dispatch signals
# ------------------------------------------
# Note: This path must be updated for your local machine. It should point to the directory containing
# downloaded monthly MMSDM data archive files.
archive_dir = r'C:\Users\eee\Desktop\nemweb\Reports\Data_Archive\MMSDM\zipped'

# Location for output files
output_dir = os.path.join(os.path.curdir, 'output')

# %% [markdown]
# ## Import generator and network information

# %%
# Generator information
df_g = pd.read_csv(os.path.join(data_dir, 'generators', 'generators.csv'), 
                   index_col='DUID', dtype={'NODE': int})

# Network node information
df_n = pd.read_csv(os.path.join(data_dir, 'network', 'network_nodes.csv'), index_col='NODE_ID')

# %% [markdown]
# ## Extract data
# Functions used to extract data from MMSDM tables.

# %%
def dispatch_unit_scada(file):
    """Extract generator dispatch data
    
    Params
    ------
    file : bytes IO object
        Zipped CSV file of given MMSDM table
    
    Returns
    -------
    df : pandas DataFrame
        MMSDM table in formatted pandas DataFrame
    """
    
    # Columns to extract    
    cols = ['DUID', 'SCADAVALUE', 'SETTLEMENTDATE']

    # Read in data
    df = pd.read_csv(file, usecols=cols, parse_dates=['SETTLEMENTDATE'], skiprows=1)

    # Drop rows without DUIDs, apply pivot
    df = df.dropna(subset=['DUID']).pivot(index='SETTLEMENTDATE', columns='DUID', values='SCADAVALUE')
    
    return df


def tradingregionsum(file):
    """Extract half-hourly load data for each NEM region
    
    Params
    ------
    file : bytes IO object
        Zipped CSV file of given MMSDM table
    
    Returns
    -------
    df : pandas DataFrame
        MMSDM table in formatted pandas DataFrame
    """

    # Columns to extract    
    cols = ['REGIONID', 'TOTALDEMAND', 'SETTLEMENTDATE']

    # Read in data
    df = pd.read_csv(file, usecols=cols, parse_dates=['SETTLEMENTDATE'], skiprows=1)

    # Drop rows without DUIDs, apply pivot
    df = df.dropna(subset=['REGIONID']).pivot(index='SETTLEMENTDATE', columns='REGIONID', values='TOTALDEMAND')

    return df  


def get_data(archive_path, table_name, extractor_function):
    """Open CSV archive and extract data from zipped file
    
    Parameters
    ----------
    archive_path : str
        Path to MMSDM archive containing data for given year
    
    table_name : str
        Name of table in MMSDM archive from which data is to be extracted
        
    extractor_function : func
        Function that takes a bytes object of the unzipped table and returns a formatted DataFrame
        
    Returns
    -------
    df : pandas DataFrame
        Formatted DataFrame of the desired MMSDM table    
    """

    # Open MMSDM archive for a given year
    with zipfile.ZipFile(archive_path) as myzip:
        
        # All files of a particular type in archive (e.g. dispatch, quantity bids, price bands, load)
        zip_names = [f for f in myzip.filelist if (table_name in f.filename) and ('.zip' in f.filename)]

        # Check that only one zip file is returned, else raise exception
        if len(zip_names) != 1:
            raise Exception('Encounted {0} files in archive, should only encounter 1'.format(len(zip_names)))

        # Get name of csv in zipped folder
        csv_name = zip_names[0].filename.replace('.zip', '.CSV').split('/')[-1]

        # Convert zip files to BytesIO object
        zip_data = BytesIO(myzip.read(zip_names[0]))

        # Open inner zipfile and extract data using supplied function
        with zipfile.ZipFile(zip_data) as z:
            with z.open(csv_name) as f:
                df = extractor_function(f)      
    return df

# Historic demand and dispatch data
demand = []
dispatch = []

for i in range(1, 13):
    # Archive name and path from which data will be extracted
    archive_name = 'MMSDM_2017_{0:02}.zip'.format(i)
    archive_path = os.path.join(archive_dir, archive_name)

    # Extract data
    dispatch.append(get_data(archive_path, 'DISPATCH_UNIT_SCADA', dispatch_unit_scada))
    demand.append(get_data(archive_path, 'TRADINGREGIONSUM', tradingregionsum))

# Concatenate data from individual months into single DataFrames for load and dispatch
df_demand = pd.concat(demand, sort=True) # Demand
df_dispatch = pd.concat(dispatch, sort=True) # Dispatch

# Fill missing values
df_demand = df_demand.fillna(0)
    
# Resample to get average power output over 30min trading interval (instead of 5min) dispatch intervals
df_dispatch = df_dispatch.resample('30min', label='right', closed='right').mean()

# %% [markdown]
# Re-index and format data:
#
# 1. identify intermittent generators (wind and solar);
# 2. identify hydro generators;
# 3. compute nodal demand;
# 4. concatenate demand, hydro dispatch, and intermittent renewables dispatch into a single DataFrame.

# %%
# Intermittent generators
mask_intermittent = df_g['FUEL_CAT'].isin(['Wind', 'Solar'])
df_g[mask_intermittent]

# Intermittent dispatch at each node
df_intermittent = (df_dispatch
                   .T
                   .join(df_g.loc[mask_intermittent, 'NODE'], how='left')
                   .groupby('NODE').sum()
                   .reindex(df_n.index, fill_value=0))
df_intermittent['level'] = 'intermittent'

# Hydro generators
mask_hydro = df_g['FUEL_CAT'].isin(['Hydro'])
df_g[mask_hydro]

# Hydro dispatch at each node
df_hydro = (df_dispatch
            .T
            .join(df_g.loc[mask_hydro, 'NODE'], how='left')
            .groupby('NODE').sum()
            .reindex(df_n.index, fill_value=0))
df_hydro['level'] = 'hydro'

# Demand at each node
def node_demand(row):
    return df_demand[row['NEM_REGION']] * row['PROP_REG_D']
df_node_demand = df_n.apply(node_demand, axis=1)
df_node_demand['level'] = 'demand'

# Concatenate intermittent, hydro, and demand series, add level to index
df_o = (pd.concat([df_node_demand, df_intermittent, df_hydro])
        .set_index('level', append=True)
        .reorder_levels(['level', 'NODE_ID']))

# %% [markdown]
# ## K-means clustering
# Construct clustering algorithm to transform the set of trading intervals into a reduced set of representative operating scenarios.

# %%
def create_scenarios(df, k=1, max_iterations=100, stopping_tolerance=100):
    """Create representative demand and fixed power injection operating scenarios

    Parameters
    ----------
    df : pandas DataFrame
        Input DataFrame from which representative operating conditions 
        should be constructed

    k : int
        Number of clusters

    max_iterations : int
        Max number of iterations used to find centroid

    stopping_tolerance : float
        Max total difference between successive centroid iteration DataFrames

    Returns
    -------
    df_clustered : pandas DataFrame
        Operating scenario centroids and their associated duration.

    centroid_history : dict
        Dictionary where keys are the iteration number and values are a DataFrame describing
        the allocation of operating conditions to centroids, and the distance between these
        values. 
    """

    # Random time periods used to initialise centroids
    random_periods = random.sample(list(df.columns), k)
    df_centroids = df[random_periods]

    # Rename centroid DataFrame columns and keep track of initial labels
    timestamp_map = {timestamp: timestamp_key + 1 for timestamp_key, timestamp in enumerate(df_centroids.columns)}
    df_centroids = df_centroids.rename(columns=timestamp_map)

    def compute_distance(col):
        """Compute distance between each data associated with each trading interval, col, and all centroids.
        Return closest centroid.

        Params
        ------
        col : pandas Series
            Operating condition for trading interval

        Returns
        -------
        closest_centroid_ID : pandas Series
            Series with ID of closest centroid and the distance to that centroid
        """

        # Initialise minimum distance between data constituting a trading interval and all centroids to an 
        # arbitrarily large number
        min_distance = 9e9
        
        # Initially no centroid is defined as being closest to the given trading interval
        closest_centroid = None

        # Compute Euclidean (2-norm) distance between the data describing a trading interval, col, and
        # all centroids. Identify the closest centroid for the given trading interval.
        for centroid in df_centroids.columns:
            distance = math.sqrt(sum((df_centroids[centroid] - col) ** 2))

            # If present value less than minimum distance, update minimum distance and record centroid
            if distance <= min_distance:
                min_distance = distance
                closest_centroid = centroid

        # Return ID of closest centroid
        closest_centroid_ID = pd.Series(data={'closest_centroid': closest_centroid, 
                                              'distance': min_distance})

        return closest_centroid_ID


    def update_centroids(row):
        "Update centroids by taking element-wise mean value of all vectors in cluster"
        
        return df[row['SETTLEMENTDATE']].mean(axis=1)

    # History of computed centroids
    centroid_history = dict()

    for i in range(max_iterations):
        # Get closest centroids for each trading interval and save result to dictionary
        df_closest_centroids = df.apply(compute_distance)
        centroid_history[i] = df_closest_centroids

        # Timestamps belonging to each cluster
        clustered_timestamps = (df_closest_centroids.loc['closest_centroid']
                                .to_frame()
                                .reset_index()
                                .groupby('closest_centroid').agg(lambda x: list(x)))

        # Update centroids by computing average nodal values across series in each cluster
        df_centroids = clustered_timestamps.apply(update_centroids, axis=1).T

        # If first iteration, set total absolute distance to arbitrarily large number
        if i == 0:
            total_absolute_distance = 1e7

            # Lagged DataFrame in next iteration = DataFrame in current iteration
            df_centroids_lag = df_centroids
        
        else:
            # Element-wise absolute difference between current and previous centroid DataFrames
            df_centroids_update_distance = abs(df_centroids - df_centroids_lag)

            # Max total element-wise distance
            total_absolute_distance = df_centroids_update_distance.sum().sum()

            # Stopping condition
            if total_absolute_distance < stopping_tolerance:
                print('Iteration number: {0}, total absolute distance: {1}. Stopping criterion satisfied. Exiting loop.'.format(i+1, total_absolute_distance))
                break
            else:
                # Continue loop 
                df_centroids_lag = df_centroids   

        print('Iteration number: {0}, total absolute distance: {1}'.format(i+1, total_absolute_distance))
        
        # Raise warning if loop terminates before stopping condition met
        if i == (max_iterations - 1):
            raise(Warning('Max iteration limit exceeded before stopping tolerance satisfied.'))


    # Get duration for each scenario
    # ------------------------------
    # Length of each trading interval (hours)
    interval_length = 0.5

    # Total number of hours for each scenario
    scenario_hours = (clustered_timestamps.apply(lambda x: len(x['SETTLEMENTDATE']), axis=1)
                      .to_frame().T
                      .mul(interval_length))

    # Renaming and setting duration index values
    scenario_hours = scenario_hours.rename(index={0: 'hours'})
    scenario_hours['level'] = 'duration'
    scenario_hours.set_index('level', append=True, inplace=True)

    # Final DataFrame with clustered values
    df_clustered = pd.concat([df_centroids, scenario_hours])

    # Convert column labels to type int
    df_clustered.columns = df_clustered.columns.astype(int)

    return df_clustered, centroid_history

# %% [markdown]
# Split time index into chunks. Each chunk corresponds to one week.

# %%
# Number of trading intervals per week = chunk size
# (7 days/week * 48 trading intervals/day = 336 trading intervals/week)
chunk_size = 336

# Map between week number and the timestamps of trading intervals for that week
week_trading_intervals_map = dict()

# For each week in the year
for week in range(1, 54):
    
    # Find timestamps corresponding to each week
    timestamps = df_o.columns[(week-1)*chunk_size:week*chunk_size]
    
    # If a full 7 days of time stamps
    if len(timestamps) == chunk_size:
        week_trading_intervals_map[week] = timestamps
    
    # Handle last week in year (less than 7 days of timestamps). Add remaining to mapping dictionary.
    else:
        week_trading_intervals_map[week-1] = week_trading_intervals_map[week-1].append(timestamps)

# %% [markdown]
# Process data for each week.

# %%
# Container for DataFrames which will contain reduced set of operating for each week
weekly_scenarios = list()

# For each week find reduced set of operating scenarios and their respective durations
for week_index, timestamps in week_trading_intervals_map.items():
    print('Processing week: {}'.format(week_index))
    
    # Get clustered scenarios
    df_clustered, _ = create_scenarios(df=df_o[timestamps], k=10, max_iterations=100, stopping_tolerance=10)
    
    # Update column index
    df_clustered.columns = pd.MultiIndex.from_product([[week_index], df_clustered.columns], names=['week', 'scenario'])
    
    # Append to list containing scenario data for each week of 2017
    weekly_scenarios.append(df_clustered)
    
# Concatenate DataFrames containing reduced set of weekly scenarios
df_weekly_scenarios = pd.concat(weekly_scenarios, axis=1)
# Out:
# Processing week: 1
# Iteration number: 1, total absolute distance: 10000000.0
# Iteration number: 2, total absolute distance: 1762.9898517956426
# Iteration number: 3, total absolute distance: 1459.4432910560088
# Iteration number: 4, total absolute distance: 550.3626240120255
# Iteration number: 5, total absolute distance: 0.0. Stopping criteria satisfied. Exiting loop.
# Processing week: 2
# Iteration number: 1, total absolute distance: 10000000.0
# Iteration number: 2, total absolute distance: 7650.235067550312
# Iteration number: 3, total absolute distance: 4559.357720662421
# Iteration number: 4, total absolute distance: 2589.637139748292
# Iteration number: 5, total absolute distance: 2434.346916613686
# Iteration number: 6, total absolute distance: 841.116572445141
# Iteration number: 7, total absolute distance: 249.92272018136845
# Iteration number: 8, total absolute distance: 176.13961476640313
# Iteration number: 9, total absolute distance: 0.0. Stopping criteria satisfied. Exiting loop.
# Processing week: 3
# Iteration number: 1, total absolute distance: 10000000.0
# Iteration number: 2, total absolute distance: 6678.017174623418
# Iteration number: 3, total absolute distance: 3409.5679563234694
# Iteration number: 4, total absolute distance: 1863.2684006098202
# Iteration number: 5, total absolute distance: 1419.8164740826269
# Iteration number: 6, total absolute distance: 1394.327147343003
# Iteration number: 7, total absolute distance: 1914.0675118948657
# Iteration number: 8, total absolute distance: 1266.8381465102816
# Iteration number: 9, total absolute distance: 1168.0867759210028
# Iteration number: 10, total absolute distance: 1787.0576369152595
# Iteration number: 11, total absolute distance: 1984.5910994073313
# Iteration number: 12, total absolute distance: 1022.5704273941003
# Iteration number: 13, total absolute distance: 1421.2812958232107
# Iteration number: 14, total absolute distance: 3794.1430959375166
# Iteration number: 15, total absolute distance: 2167.458110257383
# Iteration number: 16, total absolute distance: 1583.088356768228
# Iteration number: 17, total absolute distance: 1245.86195829637
# Iteration number: 18, total absolute distance: 765.2886030462163
# Iteration number: 19, total absolute distance: 176.59405249893672
# Iteration number: 20, total absolute distance: 83.55730363347318
# Iteration number: 21, total absolute distance: 80.41771699613035
# Iteration number: 22, total absolute distance: 68.32467322806794
# Iteration number: 23, total absolute distance: 0.0. Stopping criteria satisfied. Exiting loop.
# Processing week: 4
# Iteration number: 1, total absolute distance: 10000000.0
# Iteration number: 2, total absolute distance: 5266.937382800947
# Iteration number: 3, total absolute distance: 3738.2177226457407
# Iteration number: 4, total absolute distance: 2150.1583970114707
# Iteration number: 5, total absolute distance: 2380.149970661584
# Iteration number: 6, total absolute distance: 2842.2334039593493
# Iteration number: 7, total absolute distance: 2277.292481009738
# Iteration number: 8, total absolute distance: 1295.3703473744488
# Iteration number: 9, total absolute distance: 2041.2520191923566
# Iteration number: 10, total absolute distance: 515.5267927689902
# Iteration number: 11, total absolute distance: 171.9618768780448
# Iteration number: 12, total absolute distance: 0.0. Stopping criteria satisfied. Exiting loop.
# Processing week: 5
# Iteration number: 1, total absolute distance: 10000000.0
# Iteration number: 2, total absolute distance: 5477.418065265077
# Iteration number: 3, total absolute distance: 1997.331752667925
# Iteration number: 4, total absolute distance: 1287.561265563904
# Iteration number: 5, total absolute distance: 1182.1803203193826
# Iteration number: 6, total absolute distance: 1437.8387547549967
# Iteration number: 7, total absolute distance: 1053.2238741583938
# Iteration number: 8, total absolute distance: 585.6211882331675
# Iteration number: 9, total absolute distance: 989.83164774793
# Iteration number: 10, total absolute distance: 892.6020728300102
# Iteration number: 11, total absolute distance: 755.8498122558707
# Iteration number: 12, total absolute distance: 352.3969091395652
# Iteration number: 13, total absolute distance: 0.0. Stopping criteria satisfied. Exiting loop.
# Processing week: 6
# Iteration number: 1, total absolute distance: 10000000.0
# Iteration number: 2, total absolute distance: 5508.625528173597
# Iteration number: 3, total absolute distance: 4412.702331207099
# Iteration number: 4, total absolute distance: 3598.288139958947
# Iteration number: 5, total absolute distance: 3478.0776314618724
# Iteration number: 6, total absolute distance: 2522.409105015431
# Iteration number: 7, total absolute distance: 2527.9383295098883
# Iteration number: 8, total absolute distance: 1947.865436868324
# Iteration number: 9, total absolute distance: 1147.0601294195642
# Iteration number: 10, total absolute distance: 998.0574825822828
# Iteration number: 11, total absolute distance: 1385.3454683445889
# Iteration number: 12, total absolute distance: 2617.470839420965
# Iteration number: 13, total absolute distance: 1144.7693410434772
# Iteration number: 14, total absolute distance: 612.5837479695713
# Iteration number: 15, total absolute distance: 1334.9958709385455
# Iteration number: 16, total absolute distance: 406.268081533933
# Iteration number: 17, total absolute distance: 845.2504475979352
# Iteration number: 18, total absolute distance: 810.2829441551482
# Iteration number: 19, total absolute distance: 727.7802675966649
# Iteration number: 20, total absolute distance: 187.43651071694154
# Iteration number: 21, total absolute distance: 180.58851477658544
# Iteration number: 22, total absolute distance: 448.3979346505903
# Iteration number: 23, total absolute distance: 388.36132267140215
# Iteration number: 24, total absolute distance: 284.4000062350134
# Iteration number: 25, total absolute distance: 651.8066939359896
# Iteration number: 26, total absolute distance: 683.1698068628268
# Iteration number: 27, total absolute distance: 624.7706149361766
# Iteration number: 28, total absolute distance: 430.28131042113455
# Iteration number: 29, total absolute distance: 0.0. Stopping criteria satisfied. Exiting loop.
# Processing week: 7
# Iteration number: 1, total absolute distance: 10000000.0
# Iteration number: 2, total absolute distance: 5242.974479459927
# Iteration number: 3, total absolute distance: 3699.0651650693426
# Iteration number: 4, total absolute distance: 2765.6524068500844
# Iteration number: 5, total absolute distance: 2291.8482820892377
# Iteration number: 6, total absolute distance: 518.659910733495
# Iteration number: 7, total absolute distance: 827.6129918155088
# Iteration number: 8, total absolute distance: 761.9437987678609
# Iteration number: 9, total absolute distance: 356.99502332101144
# Iteration number: 10, total absolute distance: 0.0. Stopping criteria satisfied. Exiting loop.
# Processing week: 8
# Iteration number: 1, total absolute distance: 10000000.0
# Iteration number: 2, total absolute distance: 3108.0514756833168
# Iteration number: 3, total absolute distance: 2592.390342030531
# Iteration number: 4, total absolute distance: 2375.0662360861365
# Iteration number: 5, total absolute distance: 1675.854871825162
# Iteration number: 6, total absolute distance: 1631.4048371392653
# Iteration number: 7, total absolute distance: 1338.133973784158
# Iteration number: 8, total absolute distance: 1114.610332954782
# Iteration number: 9, total absolute distance: 462.2154756161777
# Iteration number: 10, total absolute distance: 629.3944573992526
# Iteration number: 11, total absolute distance: 1495.8596556987557
# Iteration number: 12, total absolute distance: 1060.8714672219317
# Iteration number: 13, total absolute distance: 1136.0498270977255
# Iteration number: 14, total absolute distance: 503.6089966480158
# Iteration number: 15, total absolute distance: 687.8020364595861
# Iteration number: 16, total absolute distance: 390.74853416364095
# Iteration number: 17, total absolute distance: 126.84876591332605
# Iteration number: 18, total absolute distance: 143.66737947787038
# Iteration number: 19, total absolute distance: 181.0257170723868
# Iteration number: 20, total absolute distance: 198.90505833085766
# Iteration number: 21, total absolute distance: 0.0. Stopping criteria satisfied. Exiting loop.
# Processing week: 9
# Iteration number: 1, total absolute distance: 10000000.0
# Iteration number: 2, total absolute distance: 5431.188115699128
# Iteration number: 3, total absolute distance: 2183.205574543776
# Iteration number: 4, total absolute distance: 1362.7113146233282
# Iteration number: 5, total absolute distance: 955.633619141419
# Iteration number: 6, total absolute distance: 765.001902428632
# Iteration number: 7, total absolute distance: 579.2392076964906
# Iteration number: 8, total absolute distance: 638.5094122836153
# Iteration number: 9, total absolute distance: 985.0377329240082
# Iteration number: 10, total absolute distance: 1195.7696992440654
# Iteration number: 11, total absolute distance: 973.1617677677852
# Iteration number: 12, total absolute distance: 775.4076667769015
# Iteration number: 13, total absolute distance: 534.3764490007025
# Iteration number: 14, total absolute distance: 389.43474775795573
# Iteration number: 15, total absolute distance: 635.9461926040988
# Iteration number: 16, total absolute distance: 440.5771803264721
# Iteration number: 17, total absolute distance: 364.39319823049493
# Iteration number: 18, total absolute distance: 394.6773546032683
# Iteration number: 19, total absolute distance: 126.74561913730895
# Iteration number: 20, total absolute distance: 230.7867374599349
# Iteration number: 21, total absolute distance: 411.62349047018296
# Iteration number: 22, total absolute distance: 453.54224100329475
# Iteration number: 23, total absolute distance: 624.3351892374199
# Iteration number: 24, total absolute distance: 551.3413857406988
# Iteration number: 25, total absolute distance: 306.73833594780183
# Iteration number: 26, total absolute distance: 532.29305781079
# Iteration number: 27, total absolute distance: 508.3026852484979
# Iteration number: 28, total absolute distance: 505.54069239592167
# Iteration number: 29, total absolute distance: 185.56828922273473
# Iteration number: 30, total absolute distance: 236.8631769367162
# Iteration number: 31, total absolute distance: 317.2544505122257
# Iteration number: 32, total absolute distance: 224.47670925370022
# Iteration number: 33, total absolute distance: 263.5163189148963
# Iteration number: 34, total absolute distance: 216.1427287326809
# Iteration number: 35, total absolute distance: 112.04893271635635
# Iteration number: 36, total absolute distance: 113.61650224660752
# Iteration number: 37, total absolute distance: 198.74731693130366
# Iteration number: 38, total absolute distance: 0.0. Stopping criteria satisfied. Exiting loop.
# Processing week: 10
# Iteration number: 1, total absolute distance: 10000000.0
# Iteration number: 2, total absolute distance: 2847.9042615668905
# Iteration number: 3, total absolute distance: 2030.4188931442716
# Iteration number: 4, total absolute distance: 1127.110796803459
# Iteration number: 5, total absolute distance: 652.7859195485674
# Iteration number: 6, total absolute distance: 611.5215384712951
# Iteration number: 7, total absolute distance: 937.8981750018481
# Iteration number: 8, total absolute distance: 1092.4104505024395
# Iteration number: 9, total absolute distance: 1008.5092995849407
# Iteration number: 10, total absolute distance: 735.6468258520335
# Iteration number: 11, total absolute distance: 393.64696446842913
# Iteration number: 12, total absolute distance: 0.0. Stopping criteria satisfied. Exiting loop.
# Processing week: 11
# Iteration number: 1, total absolute distance: 10000000.0
# Iteration number: 2, total absolute distance: 4390.335213235254
# Iteration number: 3, total absolute distance: 3189.4700686925585
# Iteration number: 4, total absolute distance: 2162.5396951079038
# Iteration number: 5, total absolute distance: 2660.8636422690925
# Iteration number: 6, total absolute distance: 2445.20588877998
# Iteration number: 7, total absolute distance: 699.8028798700706
# Iteration number: 8, total absolute distance: 196.33104232184195
# Iteration number: 9, total absolute distance: 238.48355289610683
# Iteration number: 10, total absolute distance: 121.2502001448685
# Iteration number: 11, total absolute distance: 0.0. Stopping criteria satisfied. Exiting loop.
# Processing week: 12
# Iteration number: 1, total absolute distance: 10000000.0
# Iteration number: 2, total absolute distance: 3330.2094015024413
# Iteration number: 3, total absolute distance: 1467.2049534028147
# Iteration number: 4, total absolute distance: 1045.9207178908061
# Iteration number: 5, total absolute distance: 1128.75169286454
# Iteration number: 6, total absolute distance: 1299.4253393898407
# Iteration number: 7, total absolute distance: 385.76141074252155
# Iteration number: 8, total absolute distance: 457.0281676388894
# Iteration number: 9, total absolute distance: 0.0. Stopping criteria satisfied. Exiting loop.
# Processing week: 13
# Iteration number: 1, total absolute distance: 10000000.0
# Iteration number: 2, total absolute distance: 4846.112993195692
# Iteration number: 3, total absolute distance: 2415.9115813386843
# Iteration number: 4, total absolute distance: 1822.8095593512874
# Iteration number: 5, total absolute distance: 1580.0617185201631
# Iteration number: 6, total absolute distance: 1263.5394044548325
# Iteration number: 7, total absolute distance: 982.8278641507977
# Iteration number: 8, total absolute distance: 1988.1853945340736
# Iteration number: 9, total absolute distance: 167.59025332478654
# Iteration number: 10, total absolute distance: 152.2112055226003
# Iteration number: 11, total absolute distance: 124.52134726175947
# Iteration number: 12, total absolute distance: 186.40511732765958
# Iteration number: 13, total absolute distance: 149.5892414581363
# Iteration number: 14, total absolute distance: 342.6475016732646
# Iteration number: 15, total absolute distance: 0.0. Stopping criteria satisfied. Exiting loop.
# Processing week: 14
# Iteration number: 1, total absolute distance: 10000000.0
# Iteration number: 2, total absolute distance: 4338.229803266201
# Iteration number: 3, total absolute distance: 1527.7219254586407
# Iteration number: 4, total absolute distance: 714.9025065760328
# Iteration number: 5, total absolute distance: 305.9968526358916
# Iteration number: 6, total absolute distance: 570.9714816110378
# Iteration number: 7, total absolute distance: 0.0. Stopping criteria satisfied. Exiting loop.
# Processing week: 15
# Iteration number: 1, total absolute distance: 10000000.0
# Iteration number: 2, total absolute distance: 3305.962305443397
# Iteration number: 3, total absolute distance: 1485.2157452631507
# Iteration number: 4, total absolute distance: 1149.3272555055544
# Iteration number: 5, total absolute distance: 878.8741636813054
# Iteration number: 6, total absolute distance: 576.7100969794197
# Iteration number: 7, total absolute distance: 219.3482351394723
# Iteration number: 8, total absolute distance: 140.57354545343145
# Iteration number: 9, total absolute distance: 189.36326380802097
# Iteration number: 10, total absolute distance: 273.65847931657834
# Iteration number: 11, total absolute distance: 0.0. Stopping criteria satisfied. Exiting loop.
# Processing week: 16
# Iteration number: 1, total absolute distance: 10000000.0
# Iteration number: 2, total absolute distance: 3462.3901378820206
# Iteration number: 3, total absolute distance: 2660.554257052856
# Iteration number: 4, total absolute distance: 2927.3410894382027
# Iteration number: 5, total absolute distance: 842.8935653002201
# Iteration number: 6, total absolute distance: 525.2968572102321
# Iteration number: 7, total absolute distance: 320.7184951552062
# Iteration number: 8, total absolute distance: 0.0. Stopping criteria satisfied. Exiting loop.
# Processing week: 17
# Iteration number: 1, total absolute distance: 10000000.0
# Iteration number: 2, total absolute distance: 8314.443596816192
# Iteration number: 3, total absolute distance: 3239.4158387013795
# Iteration number: 4, total absolute distance: 1961.6657256096262
# Iteration number: 5, total absolute distance: 1174.1420291842082
# Iteration number: 6, total absolute distance: 123.5136259724041
# Iteration number: 7, total absolute distance: 0.0. Stopping criteria satisfied. Exiting loop.
# Processing week: 18
# Iteration number: 1, total absolute distance: 10000000.0
# Iteration number: 2, total absolute distance: 5245.429575016099
# Iteration number: 3, total absolute distance: 3150.751497548064
# Iteration number: 4, total absolute distance: 1779.429893248371
# Iteration number: 5, total absolute distance: 1393.5655072923482
# Iteration number: 6, total absolute distance: 815.9989070847532
# Iteration number: 7, total absolute distance: 0.0. Stopping criteria satisfied. Exiting loop.
# Processing week: 19
# Iteration number: 1, total absolute distance: 10000000.0
# Iteration number: 2, total absolute distance: 2755.5470899880597
# Iteration number: 3, total absolute distance: 2149.0508203297477
# Iteration number: 4, total absolute distance: 940.2083989890987
# Iteration number: 5, total absolute distance: 389.7662491140549
# Iteration number: 6, total absolute distance: 126.35203392739672
# Iteration number: 7, total absolute distance: 131.4172695671375
# Iteration number: 8, total absolute distance: 0.0. Stopping criteria satisfied. Exiting loop.
# Processing week: 20
# Iteration number: 1, total absolute distance: 10000000.0
# Iteration number: 2, total absolute distance: 2870.4280482080103
# Iteration number: 3, total absolute distance: 727.3877802274488
# Iteration number: 4, total absolute distance: 557.3931973569357
# Iteration number: 5, total absolute distance: 499.0732160722322
# Iteration number: 6, total absolute distance: 279.11846088813866
# Iteration number: 7, total absolute distance: 385.0949242476543
# Iteration number: 8, total absolute distance: 0.0. Stopping criteria satisfied. Exiting loop.
# Processing week: 21
# Iteration number: 1, total absolute distance: 10000000.0
# Iteration number: 2, total absolute distance: 3785.70221885936
# Iteration number: 3, total absolute distance: 2441.4236989603382
# Iteration number: 4, total absolute distance: 1030.6501786566446
# Iteration number: 5, total absolute distance: 970.0766030251541
# Iteration number: 6, total absolute distance: 479.84856523017817
# Iteration number: 7, total absolute distance: 124.48679007764056
# Iteration number: 8, total absolute distance: 177.5253816156782
# Iteration number: 9, total absolute distance: 0.0. Stopping criteria satisfied. Exiting loop.
# Processing week: 22
# Iteration number: 1, total absolute distance: 10000000.0
# Iteration number: 2, total absolute distance: 4201.994320882043
# Iteration number: 3, total absolute distance: 2363.1545758126713
# Iteration number: 4, total absolute distance: 1499.834122748142
# Iteration number: 5, total absolute distance: 1224.4254088910816
# Iteration number: 6, total absolute distance: 897.6996012066069
# Iteration number: 7, total absolute distance: 498.16700817082346
# Iteration number: 8, total absolute distance: 551.4589040435947
# Iteration number: 9, total absolute distance: 303.235036153194
# Iteration number: 10, total absolute distance: 181.63100297806142
# Iteration number: 11, total absolute distance: 186.82436794793435
# Iteration number: 12, total absolute distance: 199.5479244324461
# Iteration number: 13, total absolute distance: 0.0. Stopping criteria satisfied. Exiting loop.
# Processing week: 23
# Iteration number: 1, total absolute distance: 10000000.0
# Iteration number: 2, total absolute distance: 5858.722305198376
# Iteration number: 3, total absolute distance: 2860.154656481032
# Iteration number: 4, total absolute distance: 1627.9141612943085
# Iteration number: 5, total absolute distance: 684.9067964831257
# Iteration number: 6, total absolute distance: 0.0. Stopping criteria satisfied. Exiting loop.
# Processing week: 24
# Iteration number: 1, total absolute distance: 10000000.0
# Iteration number: 2, total absolute distance: 3873.521828060337
# Iteration number: 3, total absolute distance: 1735.0288267260285
# Iteration number: 4, total absolute distance: 1092.2080010641248
# Iteration number: 5, total absolute distance: 615.612577571723
# Iteration number: 6, total absolute distance: 241.9189886896037
# Iteration number: 7, total absolute distance: 79.57578337368037
# Iteration number: 8, total absolute distance: 179.53291420709684
# Iteration number: 9, total absolute distance: 68.35938006280185
# Iteration number: 10, total absolute distance: 138.3056699533476
# Iteration number: 11, total absolute distance: 204.44734750993973
# Iteration number: 12, total absolute distance: 74.66921698864564
# Iteration number: 13, total absolute distance: 77.18675847949838
# Iteration number: 14, total absolute distance: 0.0. Stopping criteria satisfied. Exiting loop.
# Processing week: 25
# Iteration number: 1, total absolute distance: 10000000.0
# Iteration number: 2, total absolute distance: 3333.240766896706
# Iteration number: 3, total absolute distance: 2844.0349022572896
# Iteration number: 4, total absolute distance: 1976.7355949661471
# Iteration number: 5, total absolute distance: 1408.4959729463283
# Iteration number: 6, total absolute distance: 1611.0869448565597
# Iteration number: 7, total absolute distance: 1095.4645641371799
# Iteration number: 8, total absolute distance: 684.495051524561
# Iteration number: 9, total absolute distance: 461.3518063647951
# Iteration number: 10, total absolute distance: 376.8251375697382
# Iteration number: 11, total absolute distance: 717.494471822663
# Iteration number: 12, total absolute distance: 494.10985583669543
# Iteration number: 13, total absolute distance: 277.86632651293183
# Iteration number: 14, total absolute distance: 304.2062775183945
# Iteration number: 15, total absolute distance: 293.80954233710753
# Iteration number: 16, total absolute distance: 436.2101027810444
# Iteration number: 17, total absolute distance: 974.2624387250089
# Iteration number: 18, total absolute distance: 2294.3972060764913
# Iteration number: 19, total absolute distance: 1324.9004175764974
# Iteration number: 20, total absolute distance: 922.7005057442422
# Iteration number: 21, total absolute distance: 918.7073355955634
# Iteration number: 22, total absolute distance: 664.5914903446262
# Iteration number: 23, total absolute distance: 487.59056632158087
# Iteration number: 24, total absolute distance: 522.6250658430656
# Iteration number: 25, total absolute distance: 696.5675796426534
# Iteration number: 26, total absolute distance: 1140.9204542007
# Iteration number: 27, total absolute distance: 1299.3110402592267
# Iteration number: 28, total absolute distance: 1113.7280536072233
# Iteration number: 29, total absolute distance: 137.37202118897358
# Iteration number: 30, total absolute distance: 193.0665140750115
# Iteration number: 31, total absolute distance: 283.225498240677
# Iteration number: 32, total absolute distance: 227.26228350890904
# Iteration number: 33, total absolute distance: 408.48637361088714
# Iteration number: 34, total absolute distance: 453.00036790583283
# Iteration number: 35, total absolute distance: 244.07364685495807
# Iteration number: 36, total absolute distance: 287.68641482236
# Iteration number: 37, total absolute distance: 250.41322120934126
# Iteration number: 38, total absolute distance: 287.9087634060403
# Iteration number: 39, total absolute distance: 121.9045148336089
# Iteration number: 40, total absolute distance: 0.0. Stopping criteria satisfied. Exiting loop.
# Processing week: 26
# Iteration number: 1, total absolute distance: 10000000.0
# Iteration number: 2, total absolute distance: 4584.579443817577
# Iteration number: 3, total absolute distance: 1394.0759684276225
# Iteration number: 4, total absolute distance: 920.7285638700657
# Iteration number: 5, total absolute distance: 1259.5221027215794
# Iteration number: 6, total absolute distance: 779.1298725721855
# Iteration number: 7, total absolute distance: 293.412766603827
# Iteration number: 8, total absolute distance: 227.8552115059113
# Iteration number: 9, total absolute distance: 184.94870020130065
# Iteration number: 10, total absolute distance: 157.98312035635774
# Iteration number: 11, total absolute distance: 552.6202818750002
# Iteration number: 12, total absolute distance: 240.13456725289575
# Iteration number: 13, total absolute distance: 254.16137690998596
# Iteration number: 14, total absolute distance: 0.0. Stopping criteria satisfied. Exiting loop.
# Processing week: 27
# Iteration number: 1, total absolute distance: 10000000.0
# Iteration number: 2, total absolute distance: 3947.7176617872205
# Iteration number: 3, total absolute distance: 2286.692365734331
# Iteration number: 4, total absolute distance: 1391.6852087393
# Iteration number: 5, total absolute distance: 803.9229606822871
# Iteration number: 6, total absolute distance: 547.3140893457384
# Iteration number: 7, total absolute distance: 702.0873687216322
# Iteration number: 8, total absolute distance: 1182.641048256598
# Iteration number: 9, total absolute distance: 888.0747881583044
# Iteration number: 10, total absolute distance: 684.0970900850978
# Iteration number: 11, total absolute distance: 571.3592789884253
# Iteration number: 12, total absolute distance: 751.6078088185757
# Iteration number: 13, total absolute distance: 533.1642307390575
# Iteration number: 14, total absolute distance: 265.7131677477636
# Iteration number: 15, total absolute distance: 151.36178343355093
# Iteration number: 16, total absolute distance: 0.0. Stopping criteria satisfied. Exiting loop.
# Processing week: 28
# Iteration number: 1, total absolute distance: 10000000.0
# Iteration number: 2, total absolute distance: 5401.4773865939715
# Iteration number: 3, total absolute distance: 3674.6278957306586
# Iteration number: 4, total absolute distance: 2553.220795254305
# Iteration number: 5, total absolute distance: 896.2809532811339
# Iteration number: 6, total absolute distance: 658.6148618084426
# Iteration number: 7, total absolute distance: 537.398682713001
# Iteration number: 8, total absolute distance: 485.3830741311082
# Iteration number: 9, total absolute distance: 0.0. Stopping criteria satisfied. Exiting loop.
# Processing week: 29
# Iteration number: 1, total absolute distance: 10000000.0
# Iteration number: 2, total absolute distance: 7544.687910372243
# Iteration number: 3, total absolute distance: 4442.886570855877
# Iteration number: 4, total absolute distance: 1688.3261768987834
# Iteration number: 5, total absolute distance: 952.8843633977006
# Iteration number: 6, total absolute distance: 444.76829598857773
# Iteration number: 7, total absolute distance: 196.75217130113842
# Iteration number: 8, total absolute distance: 110.26587090448672
# Iteration number: 9, total absolute distance: 100.56579849370968
# Iteration number: 10, total absolute distance: 79.37745610314039
# Iteration number: 11, total absolute distance: 0.0. Stopping criteria satisfied. Exiting loop.
# Processing week: 30
# Iteration number: 1, total absolute distance: 10000000.0
# Iteration number: 2, total absolute distance: 5432.337284494309
# Iteration number: 3, total absolute distance: 3508.496503406847
# Iteration number: 4, total absolute distance: 1750.73468252726
# Iteration number: 5, total absolute distance: 1053.7913262414465
# Iteration number: 6, total absolute distance: 613.8765207042894
# Iteration number: 7, total absolute distance: 232.56799371394294
# Iteration number: 8, total absolute distance: 137.77679238803918
# Iteration number: 9, total absolute distance: 0.0. Stopping criteria satisfied. Exiting loop.
# Processing week: 31
# Iteration number: 1, total absolute distance: 10000000.0
# Iteration number: 2, total absolute distance: 7294.291345395219
# Iteration number: 3, total absolute distance: 4032.5723452899883
# Iteration number: 4, total absolute distance: 2189.62536218505
# Iteration number: 5, total absolute distance: 1640.723277269419
# Iteration number: 6, total absolute distance: 1670.85410544953
# Iteration number: 7, total absolute distance: 744.1474169442521
# Iteration number: 8, total absolute distance: 509.0227343250133
# Iteration number: 9, total absolute distance: 177.61814382825173
# Iteration number: 10, total absolute distance: 0.0. Stopping criteria satisfied. Exiting loop.
# Processing week: 32
# Iteration number: 1, total absolute distance: 10000000.0
# Iteration number: 2, total absolute distance: 3923.4094306685365
# Iteration number: 3, total absolute distance: 2712.3650421419334
# Iteration number: 4, total absolute distance: 2949.956194156154
# Iteration number: 5, total absolute distance: 2959.792777277819
# Iteration number: 6, total absolute distance: 1553.5331336567092
# Iteration number: 7, total absolute distance: 371.07303074114157
# Iteration number: 8, total absolute distance: 512.5592657105278
# Iteration number: 9, total absolute distance: 558.8085664183579
# Iteration number: 10, total absolute distance: 162.83136553951613
# Iteration number: 11, total absolute distance: 160.5766988543707
# Iteration number: 12, total absolute distance: 0.0. Stopping criteria satisfied. Exiting loop.
# Processing week: 33
# Iteration number: 1, total absolute distance: 10000000.0
# Iteration number: 2, total absolute distance: 4657.137490686894
# Iteration number: 3, total absolute distance: 2843.1794881205456
# Iteration number: 4, total absolute distance: 3183.4952093952156
# Iteration number: 5, total absolute distance: 2526.92910229557
# Iteration number: 6, total absolute distance: 1891.7697985746238
# Iteration number: 7, total absolute distance: 1356.844928060456
# Iteration number: 8, total absolute distance: 809.3242285593138
# Iteration number: 9, total absolute distance: 834.1436052834317
# Iteration number: 10, total absolute distance: 953.576960967659
# Iteration number: 11, total absolute distance: 1197.043777848137
# Iteration number: 12, total absolute distance: 727.048814130374
# Iteration number: 13, total absolute distance: 269.9438782064517
# Iteration number: 14, total absolute distance: 311.50066091703764
# Iteration number: 15, total absolute distance: 0.0. Stopping criteria satisfied. Exiting loop.
# Processing week: 34
# Iteration number: 1, total absolute distance: 10000000.0
# Iteration number: 2, total absolute distance: 4766.4208429341825
# Iteration number: 3, total absolute distance: 2294.008155103951
# Iteration number: 4, total absolute distance: 1637.9959026877984
# Iteration number: 5, total absolute distance: 2200.78931883635
# Iteration number: 6, total absolute distance: 1651.3656196363088
# Iteration number: 7, total absolute distance: 1929.6982643720744
# Iteration number: 8, total absolute distance: 1611.1405716007607
# Iteration number: 9, total absolute distance: 825.8763136917777
# Iteration number: 10, total absolute distance: 882.7078747412278
# Iteration number: 11, total absolute distance: 661.8822127404308
# Iteration number: 12, total absolute distance: 161.9273315986172
# Iteration number: 13, total absolute distance: 87.30845123449893
# Iteration number: 14, total absolute distance: 220.09662947227804
# Iteration number: 15, total absolute distance: 293.9131663876509
# Iteration number: 16, total absolute distance: 311.35554145717765
# Iteration number: 17, total absolute distance: 0.0. Stopping criteria satisfied. Exiting loop.
# Processing week: 35
# Iteration number: 1, total absolute distance: 10000000.0
# Iteration number: 2, total absolute distance: 3500.7743531775905
# Iteration number: 3, total absolute distance: 1958.8828617459876
# Iteration number: 4, total absolute distance: 1211.7114082276175
# Iteration number: 5, total absolute distance: 604.1193799447542
# Iteration number: 6, total absolute distance: 191.39765639012987
# Iteration number: 7, total absolute distance: 67.47104148308554
# Iteration number: 8, total absolute distance: 0.0. Stopping criteria satisfied. Exiting loop.
# Processing week: 36
# Iteration number: 1, total absolute distance: 10000000.0
# Iteration number: 2, total absolute distance: 4388.0359693938035
# Iteration number: 3, total absolute distance: 2956.149076393133
# Iteration number: 4, total absolute distance: 1684.942274130271
# Iteration number: 5, total absolute distance: 1594.4435980466665
# Iteration number: 6, total absolute distance: 784.8181324951704
# Iteration number: 7, total absolute distance: 405.2937406202598
# Iteration number: 8, total absolute distance: 205.3199575368224
# Iteration number: 9, total absolute distance: 136.18504354337236
# Iteration number: 10, total absolute distance: 90.50609247577722
# Iteration number: 11, total absolute distance: 161.9796523545395
# Iteration number: 12, total absolute distance: 210.37495396197585
# Iteration number: 13, total absolute distance: 141.10489661550002
# Iteration number: 14, total absolute distance: 0.0. Stopping criteria satisfied. Exiting loop.
# Processing week: 37
# Iteration number: 1, total absolute distance: 10000000.0
# Iteration number: 2, total absolute distance: 3687.2193129219804
# Iteration number: 3, total absolute distance: 2196.052575629382
# Iteration number: 4, total absolute distance: 1964.0265870553003
# Iteration number: 5, total absolute distance: 1828.5515353025817
# Iteration number: 6, total absolute distance: 1303.285437922714
# Iteration number: 7, total absolute distance: 2312.9602231661206
# Iteration number: 8, total absolute distance: 942.4130628883445
# Iteration number: 9, total absolute distance: 1116.200739135848
# Iteration number: 10, total absolute distance: 1191.6031985451978
# Iteration number: 11, total absolute distance: 572.9322040124794
# Iteration number: 12, total absolute distance: 293.1589213340379
# Iteration number: 13, total absolute distance: 321.76382420081734
# Iteration number: 14, total absolute distance: 0.0. Stopping criteria satisfied. Exiting loop.
# Processing week: 38
# Iteration number: 1, total absolute distance: 10000000.0
# Iteration number: 2, total absolute distance: 4703.351093800679
# Iteration number: 3, total absolute distance: 2346.4568610443325
# Iteration number: 4, total absolute distance: 1360.943913424764
# Iteration number: 5, total absolute distance: 646.6194690211755
# Iteration number: 6, total absolute distance: 0.0. Stopping criteria satisfied. Exiting loop.
# Processing week: 39
# Iteration number: 1, total absolute distance: 10000000.0
# Iteration number: 2, total absolute distance: 4455.398725382536
# Iteration number: 3, total absolute distance: 2178.829054806517
# Iteration number: 4, total absolute distance: 839.8301667511778
# Iteration number: 5, total absolute distance: 326.44360233794816
# Iteration number: 6, total absolute distance: 553.2758715135377
# Iteration number: 7, total absolute distance: 635.5876817586015
# Iteration number: 8, total absolute distance: 665.7779706805547
# Iteration number: 9, total absolute distance: 276.96864826876214
# Iteration number: 10, total absolute distance: 0.0. Stopping criteria satisfied. Exiting loop.
# Processing week: 40
# Iteration number: 1, total absolute distance: 10000000.0
# Iteration number: 2, total absolute distance: 4161.865412773946
# Iteration number: 3, total absolute distance: 2179.2294380645735
# Iteration number: 4, total absolute distance: 1097.1293519645983
# Iteration number: 5, total absolute distance: 652.4482307318655
# Iteration number: 6, total absolute distance: 0.0. Stopping criteria satisfied. Exiting loop.
# Processing week: 41
# Iteration number: 1, total absolute distance: 10000000.0
# Iteration number: 2, total absolute distance: 5436.32238711656
# Iteration number: 3, total absolute distance: 1821.406306432928
# Iteration number: 4, total absolute distance: 872.1615519903934
# Iteration number: 5, total absolute distance: 1446.1553202175674
# Iteration number: 6, total absolute distance: 1298.2148988008175
# Iteration number: 7, total absolute distance: 497.1132072264086
# Iteration number: 8, total absolute distance: 583.2595639426569
# Iteration number: 9, total absolute distance: 495.62680267316387
# Iteration number: 10, total absolute distance: 810.5454918550698
# Iteration number: 11, total absolute distance: 675.979664382041
# Iteration number: 12, total absolute distance: 600.047630282943
# Iteration number: 13, total absolute distance: 407.98652304080986
# Iteration number: 14, total absolute distance: 416.04257159624314
# Iteration number: 15, total absolute distance: 505.1401080804859
# Iteration number: 16, total absolute distance: 786.3780424860964
# Iteration number: 17, total absolute distance: 319.5852638713316
# Iteration number: 18, total absolute distance: 102.80279433727375
# Iteration number: 19, total absolute distance: 112.03207504614808
# Iteration number: 20, total absolute distance: 0.0. Stopping criteria satisfied. Exiting loop.
# Processing week: 42
# Iteration number: 1, total absolute distance: 10000000.0
# Iteration number: 2, total absolute distance: 4358.953222879681
# Iteration number: 3, total absolute distance: 2514.19759582222
# Iteration number: 4, total absolute distance: 1537.7924800371002
# Iteration number: 5, total absolute distance: 1145.4579015591428
# Iteration number: 6, total absolute distance: 1926.47129271357
# Iteration number: 7, total absolute distance: 1954.2184260836657
# Iteration number: 8, total absolute distance: 594.2917910355156
# Iteration number: 9, total absolute distance: 411.23726571206714
# Iteration number: 10, total absolute distance: 389.7069372278853
# Iteration number: 11, total absolute distance: 124.32672833077736
# Iteration number: 12, total absolute distance: 222.23856335481184
# Iteration number: 13, total absolute distance: 0.0. Stopping criteria satisfied. Exiting loop.
# Processing week: 43
# Iteration number: 1, total absolute distance: 10000000.0
# Iteration number: 2, total absolute distance: 3184.7449890688345
# Iteration number: 3, total absolute distance: 1963.4478418802983
# Iteration number: 4, total absolute distance: 1439.472212601326
# Iteration number: 5, total absolute distance: 1179.9741403166413
# Iteration number: 6, total absolute distance: 903.0090496593443
# Iteration number: 7, total absolute distance: 186.9869428182638
# Iteration number: 8, total absolute distance: 141.19415237455453
# Iteration number: 9, total absolute distance: 277.7072785402188
# Iteration number: 10, total absolute distance: 145.03801170912115
# Iteration number: 11, total absolute distance: 79.57986320112983
# Iteration number: 12, total absolute distance: 0.0. Stopping criteria satisfied. Exiting loop.
# Processing week: 44
# Iteration number: 1, total absolute distance: 10000000.0
# Iteration number: 2, total absolute distance: 4876.109208679061
# Iteration number: 3, total absolute distance: 2297.1072774580944
# Iteration number: 4, total absolute distance: 1339.0229095283696
# Iteration number: 5, total absolute distance: 455.77600775721555
# Iteration number: 6, total absolute distance: 278.1010118570041
# Iteration number: 7, total absolute distance: 299.0340456721284
# Iteration number: 8, total absolute distance: 0.0. Stopping criteria satisfied. Exiting loop.
# Processing week: 45
# Iteration number: 1, total absolute distance: 10000000.0
# Iteration number: 2, total absolute distance: 3503.405493157471
# Iteration number: 3, total absolute distance: 2575.240896344506
# Iteration number: 4, total absolute distance: 1613.4429686325489
# Iteration number: 5, total absolute distance: 795.3327155587872
# Iteration number: 6, total absolute distance: 230.21535598093033
# Iteration number: 7, total absolute distance: 0.0. Stopping criteria satisfied. Exiting loop.
# Processing week: 46
# Iteration number: 1, total absolute distance: 10000000.0
# Iteration number: 2, total absolute distance: 3948.715610650223
# Iteration number: 3, total absolute distance: 3031.070449051895
# Iteration number: 4, total absolute distance: 1394.025505378824
# Iteration number: 5, total absolute distance: 1087.6341874866303
# Iteration number: 6, total absolute distance: 275.6863577388354
# Iteration number: 7, total absolute distance: 0.0. Stopping criteria satisfied. Exiting loop.
# Processing week: 47
# Iteration number: 1, total absolute distance: 10000000.0
# Iteration number: 2, total absolute distance: 4648.088037135605
# Iteration number: 3, total absolute distance: 3124.228992928911
# Iteration number: 4, total absolute distance: 2344.18009509268
# Iteration number: 5, total absolute distance: 954.7700903252735
# Iteration number: 6, total absolute distance: 845.6900379549927
# Iteration number: 7, total absolute distance: 531.1077817000803
# Iteration number: 8, total absolute distance: 330.0533160348667
# Iteration number: 9, total absolute distance: 378.3328792732482
# Iteration number: 10, total absolute distance: 178.52639290030564
# Iteration number: 11, total absolute distance: 585.9431122704257
# Iteration number: 12, total absolute distance: 869.3136844008222
# Iteration number: 13, total absolute distance: 1069.7481645270732
# Iteration number: 14, total absolute distance: 729.1072796419678
# Iteration number: 15, total absolute distance: 417.762858690351
# Iteration number: 16, total absolute distance: 545.7186523158452
# Iteration number: 17, total absolute distance: 444.27323177553194
# Iteration number: 18, total absolute distance: 0.0. Stopping criteria satisfied. Exiting loop.
# Processing week: 48
# Iteration number: 1, total absolute distance: 10000000.0
# Iteration number: 2, total absolute distance: 3779.203093215922
# Iteration number: 3, total absolute distance: 1993.154158384274
# Iteration number: 4, total absolute distance: 1446.7420772121566
# Iteration number: 5, total absolute distance: 697.6607443040339
# Iteration number: 6, total absolute distance: 402.2114760915739
# Iteration number: 7, total absolute distance: 576.6932885529287
# Iteration number: 8, total absolute distance: 463.5900546369953
# Iteration number: 9, total absolute distance: 392.9100490118693
# Iteration number: 10, total absolute distance: 464.9600856986929
# Iteration number: 11, total absolute distance: 447.54263466768316
# Iteration number: 12, total absolute distance: 128.32307874744296
# Iteration number: 13, total absolute distance: 72.40619214961795
# Iteration number: 14, total absolute distance: 0.0. Stopping criteria satisfied. Exiting loop.
# Processing week: 49
# Iteration number: 1, total absolute distance: 10000000.0
# Iteration number: 2, total absolute distance: 3693.236338439638
# Iteration number: 3, total absolute distance: 1869.8392868233798
# Iteration number: 4, total absolute distance: 1166.0438490042848
# Iteration number: 5, total absolute distance: 1179.8504638388729
# Iteration number: 6, total absolute distance: 542.8550310958408
# Iteration number: 7, total absolute distance: 299.9784527028726
# Iteration number: 8, total absolute distance: 265.64863996259004
# Iteration number: 9, total absolute distance: 74.138493792124
# Iteration number: 10, total absolute distance: 76.93718825962654
# Iteration number: 11, total absolute distance: 75.79447271203642
# Iteration number: 12, total absolute distance: 0.0. Stopping criteria satisfied. Exiting loop.
# Processing week: 50
# Iteration number: 1, total absolute distance: 10000000.0
# Iteration number: 2, total absolute distance: 7469.490380292052
# Iteration number: 3, total absolute distance: 4699.695643754957
# Iteration number: 4, total absolute distance: 3632.0974373175864
# Iteration number: 5, total absolute distance: 1689.6190160645278
# Iteration number: 6, total absolute distance: 625.5577270849241
# Iteration number: 7, total absolute distance: 0.0. Stopping criteria satisfied. Exiting loop.
# Processing week: 51
# Iteration number: 1, total absolute distance: 10000000.0
# Iteration number: 2, total absolute distance: 6735.026918048495
# Iteration number: 3, total absolute distance: 3503.3447766223653
# Iteration number: 4, total absolute distance: 2147.3299125016533
# Iteration number: 5, total absolute distance: 781.6689341073841
# Iteration number: 6, total absolute distance: 893.5339431067401
# Iteration number: 7, total absolute distance: 0.0. Stopping criteria satisfied. Exiting loop.
# Processing week: 52
# Iteration number: 1, total absolute distance: 10000000.0
# Iteration number: 2, total absolute distance: 3588.3147131912115
# Iteration number: 3, total absolute distance: 2484.7535798079966
# Iteration number: 4, total absolute distance: 1677.33479134316
# Iteration number: 5, total absolute distance: 555.3310833315101
# Iteration number: 6, total absolute distance: 655.3357280573764
# Iteration number: 7, total absolute distance: 798.687129822759
# Iteration number: 8, total absolute distance: 889.4497531336823
# Iteration number: 9, total absolute distance: 679.1038566020957
# Iteration number: 10, total absolute distance: 697.7847845339627
# Iteration number: 11, total absolute distance: 409.11345137450985
# Iteration number: 12, total absolute distance: 121.51254323372243
# Iteration number: 13, total absolute distance: 228.17339640795964
# Iteration number: 14, total absolute distance: 160.32994098981123
# Iteration number: 15, total absolute distance: 153.69388127910042
# Iteration number: 16, total absolute distance: 0.0. Stopping criteria satisfied. Exiting loop.

# %% [markdown]
# ## Save data

# %%
with open(os.path.join(output_dir, 'weekly_scenarios.pickle'), 'wb') as f:
    pickle.dump(df_weekly_scenarios, f)

# %% [markdown]
# ## References
# [1] - Australian Energy Markets Operator. Data Archive (2018). at [http://www.nemweb.com.au/#mms-data-model:download](http://www.nemweb.com.au/#mms-data-model:download)
#
# [2] - Baringo L., Conejo, A. J., Correlated wind-power production and electric load scenarios for investment decisions. Applied Energy (2013).
#
# [3] - Xenophon A. K., Hill D. J., Geospatial modelling of Australia's National Electricity Market allowing backtesting against historic data.  Scientific Data (2018).
#
# [4] - Xenophon A. K., Hill D. J., Geospatial Modelling of Australia's National Electricity Market - Dataset (Version v1.3) [Data set]. Zenodo. [http://doi.org/10.5281/zenodo.1326942](http://doi.org/10.5281/zenodo.1326942)
